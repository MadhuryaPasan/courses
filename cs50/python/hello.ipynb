# %%
# ask user for their name
name = input("what's is your name?").strip().title()

# split user's name into first name and last name
first, last = name.split(" ")  # split with a space

# say hello to user
print(f"Hello, {first}")
# Out:
# Hello, Pasan

# %% [markdown]
# ## int
#
# support + - \* / %

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# ## calculator

# %%
x = 1
y = 2

z = x + y

print(z)
# Out:
# 3

# %%
x = input("What's x?")
y = input("What's y?")

z = int(x) + int(y)  # converting string to int

print(z)
# Out:
# 5

# %%
# reduce the code

x = int(input("What's x?"))
y = int(input("What's y?"))

print(x + y)
# Out:
# 5

# %% [markdown]
# ## float

# %%
x = float(input("What's x?"))
y = float(input("What's y?"))

print(x + y)
# Out:
# 5.0

# %% [markdown]
# ## round
#
# round(number[,ndigits])
# `[ ] -> means that, inside of this is optional items`

# %%
x = float(input("What's x?"))
y = float(input("What's y?"))

z = round(x + y)

print(z)
# Out:
# 6

# %%
x = float(input("What's x?"))
y = float(input("What's y?"))

z = round(x / y, 2)  # round up to last 2 decimal points

print(z)
# Out:
# 6.38

# %%
# using format string (f-string)

x = float(input("What's x?"))
y = float(input("What's y?"))

z = x / y

print(f"{z:.2f}")
# Out:
# 5.64

# %% [markdown]
# ## formating number output
#
# `1000 -> 1,000`

# %%
x = float(input("What's x?"))
y = float(input("What's y?"))

z = round(x + y)

print(f"{z:,}")
# Out:
# 11,000,000

# %% [markdown]
# ## def
#
# ~define~

# %%
def hello():
    print("hello")


name = input("What's your name? ")
hello()
print(name)
# Out:
# hello
# pasan

# %%
# include print function in def


def hello(to):
    print("hello,", to)


name = input("What's your name? ")
hello(name)
# Out:
# hello, pasan

# %%
# default value
def hello(to="World"):
    print("hello,", to)


name = input("What's your name? ")
hello(name)
hello()
# Out:
# hello, pasan
# hello, World

# %% [markdown]
# ## def main():

# %%
def main():
    name = input("What's your name? ")
    hello(name)


def hello(to="World"):
    print("hello,", to)


main()

# now the hello function can be included below the main.

# %% [markdown]
# ## scope
#
# region of a program where a variable is accessible

# %%
def main():
    name = input("What's your name? ")
    hello()


def hello():
    print("hello,", name)


main()

# ! this will display an error

# %% [markdown]
# ## return

# %%
# calculator.py


def main():
    x = int(input("What's x?"))
    print("x squared is ", square(x))


def square(n):
    return n * n
    # return n**2
    # return pow(n, 2)


main()
# Out:
# x squared is  25

# %% [markdown]
# `video time -> 1:50:18`

# %% [markdown]
# > # Conditionals
# >
# > `> >= < <= == !=`

# %%
# compare.py
x = int(input("what's x? "))
y = int(input("what's y?"))

if x < y:
    print("x is less than y")
if x > y:
    print("x is greater than y")
if x == y:
    print("x is equal to y")

# %%
x = int(input("what's x? "))
y = int(input("what's y?"))

if x < y:
    print("x is less than y")
elif x > y:
    print("x is greater than y")
elif x == y:
    print("x is equal to y")

# %%
x = int(input("what's x? "))
y = int(input("what's y?"))

if x < y:
    print("x is less than y")
elif x > y:
    print("x is greater than y")
else:
    print("x is equal to y")

# %%
x = int(input("what's x? "))
y = int(input("what's y?"))

if x < y or x > y:
    print("x is not equal to y")
else:
    print("x is equal to y")

# %%
x = int(input("what's x? "))
y = int(input("what's y?"))

if x != y:
    print("x is not equal to y")
else:
    print("x is equal to y")

# %%
x = int(input("what's x? "))
y = int(input("what's y?"))

if x == y:
    print("x is equal to y")
else:
    print("x is not equal to y")

# %%
# grade.py

score = int(input("Score: "))

if score >= 90 and score <= 100:
    print("Grade: A")
elif score >= 80 and score < 90:
    print("Grade: B")
elif score >= 70 and score < 80:
    print("Grade: C")
elif score >= 60 and score < 70:
    print("Grade: D")
else:
    print("Grade: F")

# %%
# reducing the code size
score = int(input("Score: "))

if 90 <= score <= 100:
    print("Grade: A")
elif 80 <= score < 90:
    print("Grade: B")
elif 70 <= score < 80:
    print("Grade: C")
elif 60 <= score < 70:
    print("Grade: D")
else:
    print("Grade: F")

# %%
# reducing the code size
score = int(input("Score: "))

if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
elif score >= 70:
    print("Grade: C")
elif score >= 60:
    print("Grade: D")
else:
    print("Grade: F")

# %%
# parity.py

x = int(input("what's x? "))

if x % 2 == 0:
    print("Even")
else:
    print("Odd")

# %%
def main():
    x = int(input("what's x?"))
    if is_even(x):
        print("Even")
    else:
        print("Odd")


def is_even(n):
    if n % 2 == 0:
        return True
    else:
        return False


main()

# %% [markdown]
# `video time -> 2.34.23`

# %%
# less code
def main():
    x = int(input("what's x?"))
    if is_even(x):
        print("Even")
    else:
        print("Odd")


def is_even(n):
    return True if n % 2 == 0 else False


main()

# %%
# less code
def main():
    x = int(input("what's x?"))
    if is_even(x):
        print("Even")
    else:
        print("Odd")


def is_even(n):
    return n % 2 == 0


main()

# %%
# house.py
name = input("What's your name?")

if name == "Harry":
    print("Gryffindor")
elif name == "Hermione":
    print("Gryffindor")
elif name == "Ron":
    print("Gryffindor")
elif name == "Draco":
    print("Slytherin")
else:
    print("Who?")

# %%
name = input("What's your name?")

if name == "Harry" or name == "Hermione" or name == "Ron":
    print("Gryffindor")
elif name == "Draco":
    print("Slythering")
else:
    print("Who?")

# %% [markdown]
# ## match - case

# %%
name = input("What's your name? ")

match name:
    case "Harry":
        print("Gryffindor")
    case "Hermione":
        print("Gryffindor")
    case "Ron":
        print("Gryffindor")
    case "Draco":
        print("Slythering")
    case _:
        print("Who?")

# %%
# short code

name = input("What's your name?")

match name:
    case "Harry" | "Hermione" | "Ron":
        print("Gryffindor")
    case "Draco":
        print("Slythering")
    case _:
        print("Who?")

# %% [markdown]
# > # Loops

# %%
print("meow")
print("meow")
print("meow")
print("meow")

# %% [markdown]
# ## while

# %%
i = 3

while i != 0:
    print("meow")
    i = i - 1

# %%
i = 1

while i <= 3:
    print("meow")
    i = i + 1

# %%
i = 0
while i < 3:
    print("meow")
    i = i + 1

# %%
i = 0
while i < 3:
    print("meow")
    i += 1  # short one

# %% [markdown]
# ## for

# %%
for i in [0, 1, 2]:  # this is a list
    print("meow")
# Out:
# meow
# meow
# meow

# %%
for i in range(3):
    print("meow")
# Out:
# meow
# meow
# meow

# %%
for _ in range(3):
    print("meow")
# Out:
# meow
# meow
# meow

# %%
print("meow\n" * 3, end="")
print("--")
# Out:
# meow
# meow
# meow
# --

# %%
while True:
    n = int(input("What's n?"))
    if n < 0:
        continue
    else:
        break

# %%
while True:
    n = int(input("What's n?"))
    if n > 0:
        break

for _ in range(n):
    print("meow")
# Out:
# meow
# meow
# meow
# meow
# meow

# %%
# cat.py


def main():
    meow(3)


def meow(n):
    for _ in range(n):
        print("meow")


main()

# %%
def main():
    number = get_number()
    meow(number)


def get_number():
    while True:
        n = int(input("What's n?"))
        if n > 0:
            return n


# or
# def get_number():
#     while True:
#         n = int(input("What's n?"))
#         if n > 0:
#             break
#     return n


def meow(n):
    for _ in range(n):
        print("meow")


main()

# %% [markdown]
# ## list

# %%
students = ["Hermione", "Harry", "Ron"]

print(students)
print(students[0])
# Out:
# ['Hermione', 'Harry', 'Ron']
# Hermione

# %%
students = ["Hermione", "Harry", "Ron"]
for student in students:
    print(student)
# Out:
# Hermione
# Harry
# Ron

# %%
students = ["Hermione", "Harry", "Ron"]

for i in range(len(students)):
    print(i + 1, students[i])
# Out:
# 1 Hermione
# 2 Harry
# 3 Ron

# %% [markdown]
# `video time -> 3.32.10`

# %% [markdown]
# ## dict
#
# `{key:value}`

# %%
# students = ["Hermione","Harry","Ron","Draco"]
# houses = ["Gryffindor","Gryffindor","Gryffindor","Slytherin"]

students = {
    "Hermione": "Gryffindor",
    "Harry": "Gryffindor",
    "Ron": "Gryffindor",
    "Draco": "Slythering",
}

print(students["Hermione"])
print(students["Harry"])
# Out:
# Gryffindor
# Gryffindor

# %%
students = {
    "Hermione": "Gryffindor",
    "Harry": "Gryffindor",
    "Ron": "Gryffindor",
    "Draco": "Slythering",
}

for student in students:
    print(student)  # only the keys
# Out:
# Hermione
# Harry
# Ron
# Draco

# %%
students = {
    "Hermione": "Gryffindor",
    "Harry": "Gryffindor",
    "Ron": "Gryffindor",
    "Draco": "Slythering",
}

for student in students:
    print(student, students[student], sep=", ")
# Out:
# Hermione, Gryffindor
# Harry, Gryffindor
# Ron, Gryffindor
# Draco, Slythering

# %%
students = [
    {"name": "Hermione", "house": "Gryffindor", "patronus": "Otter"},
    {"name": "Harry", "house": "Gryffindor", "patronus": "Stag"},
    {"name": "Ron", "house": "Gryffindor", "patronus": "Jack Russell terrier"},
    {"name": "Draco", "house": "Slythering", "patronus": None},
]

for student in students:
    print(student["name"], student["house"], student["patronus"], sep=", ")
# Out:
# Hermione, Gryffindor, Otter
# Harry, Gryffindor, Stag
# Ron, Gryffindor, Jack Russell terrier
# Draco, Slythering, None

# %%
# mario.py

print("#")
print("#")
print("#")
# Out:
# #
# #
# #

# %%
for _ in range(3):
    print("#")
# Out:
# #
# #
# #

# %%
# cols
def main():
    print_column(3)


def print_column(height):
    for _ in range(height):
        print("#")


main()
# Out:
# #
# #
# #

# %%
def main():
    print_column(3)


def print_column(height):
    print("#\n" * height, end="")


main()
# Out:
# #
# #
# #

# %%
# rows
def main():
    print_row(4)


def print_row(width):
    print("?" * width)


main()
# Out:
# ????

# %%
# square
def main():
    print_square(3)


def print_square(size):

    # For each row in square
    for i in range(size):

        # For each brick in row
        for j in range(size):

            # Print brick
            print("#", end="")
        print()


main()
# Out:
# ###
# ###
# ###

# %%
# shorted


def main():
    print_square(3)


def print_square(size):
    for _ in range(size):
        print("#" * size)


main()
# Out:
# ###
# ###
# ###

# %%
def main():
    print_square(3)


def print_square(size):
    for _ in range(size):
        print_row(size)


def print_row(width):
    print("#" * width)


main()
# Out:
# ###
# ###
# ###

# %% [markdown]
# `video time -> 4:07:30`

# %% [markdown]
# > # Exceptions

# %% [markdown]
# ### The "Must Know" Common Exceptions
#
# While there are dozens of exceptions, as a developer, you will encounter these 10 roughly 90% of the time.
#
# | Exception               | Cause                                                      | Example                                                   |
# | :---------------------- | :--------------------------------------------------------- | :-------------------------------------------------------- |
# | **`SyntaxError`**       | You wrote invalid Python code (e.g., missed a colon).      | `if x == 5` (missing `:`)                                 |
# | **`TypeError`**         | Operation on the wrong type of object.                     | `"Age: " + 25` (cannot add str and int)                   |
# | **`ValueError`**        | Right type, but inappropriate value.                       | `int("hello")` (string is valid type, but content is bad) |
# | **`IndexError`**        | Trying to access a list index that doesn't exist.          | `my_list[10]` (when list has only 3 items)                |
# | **`KeyError`**          | Trying to access a dictionary key that isn't there.        | `my_dict["unknown_key"]`                                  |
# | **`AttributeError`**    | Trying to access a method/variable an object doesn't have. | `variable.append()` (if variable is an Integer)           |
# | **`NameError`**         | Using a variable that hasn't been defined yet.             | `print(x)` (where x was never assigned)                   |
# | **`ZeroDivisionError`** | Dividing a number by zero.                                 | `10 / 0`                                                  |
# | **`FileNotFoundError`** | Trying to open a file that doesn't exist.                  | `open("missing.txt")`                                     |
# | **`ImportError`**       | Python cannot find the module you are trying to import.    | `import nomodule`                                         |
#
# ---
#
# ### The Complete Hierarchy (Python 3.x)
#
# Here is the structured tree of all built-in exceptions.
#
# #### A. The Root Exceptions
#
# These are the fundamental base classes. You usually do **not** catch `BaseException` directly.
#
# - **`BaseException`**: The root of all exceptions.
#   - **`SystemExit`**: Raised by `sys.exit()`.
#   - **`KeyboardInterrupt`**: Raised when you press **Ctrl+C**.
#   - **`GeneratorExit`**: Raised when a generator is closed.
#   - **`Exception`**: **This is the base class for all non-system-exiting exceptions.** (User-defined exceptions should inherit from this).
#
# #### B. Concrete Exceptions (Under `Exception`)
#
# These are the errors you will handle in your logic.
#
# - **`ArithmeticError`** (Base class for math errors)
#   - `FloatingPointError`
#   - `OverflowError`
#   - `ZeroDivisionError`
# - **`AssertionError`** (Raised by `assert` statement)
# - **`AttributeError`**
# - **`BufferError`**
# - **`EOFError`** (End Of File, e.g., hitting Ctrl+D in `input()`)
# - **`ImportError`**
#   - `ModuleNotFoundError`
# - **`LookupError`** (Base for finding items)
#   - `IndexError`
#   - `KeyError`
# - **`MemoryError`**
# - **`NameError`**
#   - `UnboundLocalError`
# - **`OSError`** (Base for Operating System errors)
#   - `BlockingIOError`
#   - `ChildProcessError`
#   - `ConnectionError`
#     - `BrokenPipeError`
#     - `ConnectionAbortedError`
#     - `ConnectionRefusedError`
#     - `ConnectionResetError`
#   - `FileExistsError`
#   - `FileNotFoundError`
#   - `InterruptedError`
#   - `IsADirectoryError`
#   - `NotADirectoryError`
#   - `PermissionError`
#   - `ProcessLookupError`
#   - `TimeoutError`
# - **`ReferenceError`** (Weak reference proxy access)
# - **`RuntimeError`**
#   - `NotImplementedError`
#   - `RecursionError` (Maximum recursion depth exceeded)
# - **`StopIteration`** (Signals the end of an iterator)
# - **`StopAsyncIteration`**
# - **`SyntaxError`**
#   - `IndentationError`
#     - `TabError`
# - **`SystemError`** (Internal interpreter error)
# - **`TypeError`**
# - **`ValueError`**
#   - `UnicodeError`
#     - `UnicodeDecodeError`
#     - `UnicodeEncodeError`
#     - `UnicodeTranslateError`
#
# #### C. Warnings
#
# These are printed to the console but generally do not stop the program execution unless configured to do so.
#
# - **`Warning`**
#   - `DeprecationWarning` (Feature will be removed in future)
#   - `PendingDeprecationWarning`
#   - `RuntimeWarning`
#   - `SyntaxWarning`
#   - `UserWarning`
#   - `FutureWarning`
#   - `ImportWarning`
#   - `UnicodeWarning`
#   - `BytesWarning`
#   - `ResourceWarning`

# %%
# print("hello, world) # SyntaxError
print("hello, world")
# Out:
# hello, world

# %%
# number.py

x = int(input("What's x?"))
print(f"x is {x}")


# if we give cat as a input this will be the error
# ValueError: invalid literal for int() with base 10: 'cat'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 3
#       1 # number.py
# ----> 3 x = int(input("What's x?"))
#       4 print(f"x is {x}")
#       7 # if we give cat as a input this will be the error
#       8 # ValueError: invalid literal for int() with base 10: 'cat'
#
# ValueError: invalid literal for int() with base 10: 'cat'

# %% [markdown]
# # try and except

# %%
try:
    x = int(input("What's x?"))
    print(f"x is {x}")
except ValueError:
    print("x is not an integer")
# Out:
# x is not an integer

# %%
# only add the code that might causes a exception

try:
    x = int(input("What's x?"))
except ValueError:
    print("x is not an integer")

print(f"x is {x}")

# if now enterd cat -> NameError: name 'x' is not defined
# Out:
# x is not an integer
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 except ValueError:
#       6     print("x is not an integer")
# ----> 8 print(f"x is {x}")
#      10 # if now enterd cat -> NameError: name 'x' is not defined
#
# NameError: name 'x' is not defined

# %% [markdown]
# ## try except else

# %%
try:
    x = int(input("What's x?"))
except:
    print("x in not an integer")
else:
    print(f"x is {x}")

# this is handle value error
# Out:
# x in not an integer

# %%
while True:
    try:
        x = int(input("What's x?"))
    except:
        print("x in not an integer")
    else:
        break

print(f"x is {x}")
# Out:
# x in not an integer
# x in not an integer
# x is 4

# %%
# in a funtion
def main():
    x = get_int()
    print(f"x is {x}")


def get_int():
    while True:
        try:
            x = int(input("What's x?"))
        except:
            print("Error: x in not an integer")
        else:
            break
    return x


main()
# Out:
# Error: x in not an integer
# x is 4

# %%
# return can act as a `break`


def main():
    x = get_int()
    print(f"x is {x}")


def get_int():
    while True:
        try:
            x = int(input("What's x?"))
        except:
            print("Error: x in not an integer")
        else:
            return x


main()
# Out:
# Error: x in not an integer
# x is 2

# %%
# shorted
def main():
    x = get_int()
    print(f"x is {x}")


def get_int():
    while True:
        try:
            return int(input("What's x?"))
        except:
            print("Error: x in not an integer")


main()
# Out:
# Error: x in not an integer
# x is 3

# %% [markdown]
# ## try except pass
#
# `pass -> pass the handling the error`

# %%
def main():
    x = get_int()
    print(f"x is {x}")


def get_int():
    while True:
        try:
            return int(input("What's x?"))
        except:
            pass


main()
# Out:
# x is 1

# %%
def main():
    x = get_int("What's x?")
    print(f"x is {x}")


def get_int(promt):
    while True:
        try:
            return int(input(promt))
        except:
            pass


main()
# Out:
# x is 3

# %% [markdown]
# `video time -> 4:52:06`

# %% [markdown]
# > # Libraries

# %% [markdown]
# | Term        | Definition                                                                                                                                                                                               | Example                                                                                         |
# | :---------- | :------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | :---------------------------------------------------------------------------------------------- |
# | **Module**  | A single file (`.py`) containing code. This is the **most basic unit**.                                                                                                                                  | `math.py`                                                                                       |
# | **Package** | A directory (folder) that contains multiple modules and a special file named `__init__.py`. Packages allow for **structuring the module namespace** using "dotted module names" (e.g., `requests.auth`). | The `requests` directory containing modules like `requests/auth.py`, `requests/models.py`, etc. |
# | **Library** | A **collection** of related packages and modules. This is a very broad, general term for any code that provides useful functionality (a module or a package can be considered a small library).          | The entire **SciPy** collection of packages, or the **Python Standard Library**.                |

# %%
# generate.py
import random

coin = random.choice(["head", "tail"])
print(coin)
# this is better sometimes
# Out:
# head

# %%
from random import choice

coin = choice(["head", "tail"])
print(coin)
# Out:
# head

# %%
import random

number = random.randint(1, 10)
print(number)
# Out:
# 8

# %%
import random

cards = ["jack", "queen", "king"]
random.shuffle(cards)
for card in cards:
    print(card)
# Out:
# king
# queen
# jack

# %%
# statistics module
import statistics

import statistics

print(statistics.mean([100, 90]))
# Out:
# 95

# %% [markdown]
# ## command-line arguments
#
# eg -> python hello.py

# %% [markdown]
# `sys.argv` is a specific variable (a **list**) found in Python's standard `sys` module. It is used to handle **command-line arguments**.
#
# When you run a Python script from your terminal or command prompt, `sys.argv` captures the inputs you provide after the script name and makes them available to your code.
#
# Here is the breakdown of the name:
#
# - **sys**: The module containing system-specific parameters and functions.
# - **argv**: Short for **"Argument Vector"** (a term inherited from the C programming language), which essentially means a list of argument values.
#
# ---
#
# ## 🧐 How it Works
#
# `sys.argv` is a simple **Python list of strings**.
#
# When you execute a command in your terminal, Python takes that line of text, splits it by spaces, and stores the pieces in this list.
#
# ### The Structure of the List
#
# The most important thing to remember is how the indices are assigned:
#
# 1.  **`sys.argv[0]`**: This is **always the name of the script** (the program itself).
# 2.  **`sys.argv[1]`**: This is the **first argument** you passed.
# 3.  **`sys.argv[2]`**: This is the **second argument**, and so on.
#
# ---
#
# ## 💻 Code Example
#
# Imagine you have a file named `greet.py` with the following code:
#
# ```python
# import sys
#
# # Check if the list contains more than just the script name
# # (meaning the user actually typed an argument)
# if len(sys.argv) > 1:
#     # Get the first argument (index 1)
#     name = sys.argv[1]
#     print(f"Hello, {name}!")
# else:
#     print("Hello, Stranger!")
#
# # Let's print the whole list to see what it looks like
# print(f"\nRaw list data: {sys.argv}")
# ```
#
# ### Running the Code
#
# Here is how this script behaves depending on what you type in your terminal:
#
# **Scenario A: No arguments provided**
#
# ```bash
# $ python greet.py
# ```
#
# - **Output:** `Hello, Stranger!`
# - **Raw list:** `['greet.py']`
#
# **Scenario B: One argument provided**
#
# ```bash
# $ python greet.py Alice
# ```
#
# - **Output:** `Hello, Alice!`
# - **Raw list:** `['greet.py', 'Alice']`
#
# **Scenario C: Multiple arguments provided**
#
# ```bash
# $ python greet.py Alice Bob
# ```
#
# - **Output:** `Hello, Alice!` (The script ignores 'Bob' because we only asked for `sys.argv[1]`)
# - **Raw list:** `['greet.py', 'Alice', 'Bob']`
#
# ---
#
# ## ⚠️ Important "Gotchas"
#
# ### 1\. Everything is a String
#
# `sys.argv` always stores arguments as **strings**, even if you type numbers. You must convert them manually if you need to do math.
#
# ```bash
# $ python add.py 5 5
# ```
#
# If you just do `sys.argv[1] + sys.argv[2]`, Python will output `"55"` (string concatenation).
# You must do `int(sys.argv[1]) + int(sys.argv[2])` to get `10`.
#
# ### 2\. Spaces Break Arguments
#
# The terminal uses spaces to separate arguments. If you want to pass a single argument that contains spaces (like a full name), you must use quotes.
#
# ```bash
# $ python greet.py "John Smith"
# ```
#
# - `sys.argv[1]` is now `"John Smith"`.
# - Without quotes, `John` would be `[1]` and `Smith` would be `[2]`.

# %%
# sys
# check sys.py for this
import sys

print("hello, my name is", sys.argv[1])

# when run the py file run like this
# python sys.py pasan
# Out:
# hello, my name is --f=c:\Users\pkmpp\AppData\Roaming\jupyter\runtime\kernel-v3069d192f666ca9e4bb9da5dbc6c730e10a6cea2e.json

# %% [markdown]
# ## packages
#
# PyPI -> python package index

# %%
# %pip install cowsay
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script cowsay.exe is installed in 'c:\Users\pkmpp\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# check say.py for this

# %% [markdown]
# ## APIs

# %%
# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# https://itunes.apple.com/search?entity=song&limit=1&term=weezer

# %%
# check itunes.py for this

# %%
import requests
import json

limit = 1000
artist = "martingarrix"
response = requests.get(
    "https://itunes.apple.com/search?entity=song&limit="
    + str(limit)
    + "&term="
    + artist
)
# print(json.dumps(response.json(), indent=2)) #this will format into proper json

o = response.json()
count = 1
for result in o["results"]:
    print(count, result["trackName"])
    count = count + 1
# Out:
# 1 Ocean (feat. Khalid)
# 2 High on Life (feat. Bonn)
# 3 In the Name of Love
# 4 Scared to Be Lonely
# 5 Don't Look Down (feat. Usher)
# 6 There for You
# 7 MAD
# 8 So Far Away (feat. Jamie Scott & Romy Dya)
# 9 Virus (How About Now) [Radio Edit]
# 10 Like I Do
# 11 Forbidden Voices
# 12 No Sleep (feat. Bonn)
# 13 Pressure (feat. Tove Lo)
# 14 Drown (feat. Clinton Kane)
# 15 Used To Love
# 16 Hero
# 17 Pizza
# 18 Higher Ground (feat. John Martin)
# 19 Sleepless Nights (feat. Libby Whitehouse)
# 20 Now That I've Found You (feat. John & Michel)
# 21 Real Love
# 22 Follow
# 23 Animals
# 24 Scared to Be Lonely (Acoustic Version)
# 25 Burn Out (feat. Dewain Whitmore)
# 26 Told You So
# 27 Hurricane (feat. Bonn)
# 28 In the Name of Love (DallasK Remix)
# 29 We Are the People (feat. Bono & The Edge)
# 30 Home (feat. Bonn)
# 31 Scared to Be Lonely (Brooks Remix)
# 32 These Are the Times (feat. JRM)
# 33 Mistaken (feat. Alex Aris)
# 34 Waiting for Tomorrow (feat. Mike Shinoda)
# 35 Poison
# ...

# %% [markdown]
# ## creating a own module/ library

# %%
# check sayings.py

# %% [markdown]
# `video time: -> 6:09:32`

# %% [markdown]
# > # Unit Tests

# %%
# check Unit test folder

# %% [markdown]
# `assert`
#
# library for testing `pytest`

# %%
# %pip install pytest
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# `video time -> 7:00:30`

# %% [markdown]
# > # File I/O

# %%
# names.py
names = []

for _ in range(3):
    names.append(input("What's your name?"))

for name in sorted(names):
    print(f"hello, {name}")
# Out:
# hello, Harry
# hello, Hermione
# hello, Ron

# %%
name = input("What's your name?")

file = open("names.txt", "w")  # w for write and this will create a new file
file.write(name)
file.close()

#! this rewrite the previous name on the name.txt

# %%
name = input("What's your name?")

file = open("names.txt", "a")  # a for append
file.write(f"{name}\n")  # write with new lines
file.close()

# %% [markdown]
# `with` -> used to automaticaly open and close files

# %%
name = input("What's your name?")

with open("names.txt", "a") as file:
    file.write(f"{name}\n")

# %% [markdown]
# `rstrip()` -> removes all witespaces
#
# Spaces (' ')
#
# Newlines ('\n')
#
# Tabs ('\t')
#
# Carriage returns ('\r')
#
# Form feeds ('\f')

# %%
with open("names.txt", "r") as file:
    lines = file.readlines()

for line in lines:
    # print("hello,", line, end="")
    print("hello,", line.rstrip())
# Out:
# hello, Hermione
# hello, Harry
# hello, Ron

# %%
# short way
with open("names.txt", "r") as file:
    for line in file:
        print("hello,", line.rstrip())
# Out:
# hello, Hermione
# hello, Harry
# hello, Ron

# %%
# use sort
names = []

with open(
    "names.txt"
) as file:  # not need "r". because the default value for open is "r"
    for line in file:
        names.append(line.rstrip())

for name in sorted(names):
    print(f"hello, {name}")
# Out:
# hello, Harry
# hello, Hermione
# hello, Ron

# %%
# more short way

with open("names.txt") as file:
    for line in sorted(file):
        print("hello,", line.rstrip())
# Out:
# hello, Harry
# hello, Hermione
# hello, Ron

# %%
# use sort
names = []

with open("names.txt") as file:
    for line in file:
        names.append(line.rstrip())

for name in sorted(names, reverse=True):
    print(f"hello, {name}")
# Out:
# hello, Ron
# hello, Hermione
# hello, Harry

# %%
# students.py

with open("students.csv") as file:
    for line in file:
        row = line.rstrip().split(",")
        print(f"{row[0]} is in {row[1]}")
# Out:
# Hermione is in Gryffingor
# Harry is in Gryffingor
# Ron is in Gryffingor
# Draco is in Slythering

# %%
with open("students.csv") as file:
    for line in file:
        name, house = line.rstrip().split(",")
        print(f"{name} is in {house}")
# Out:
# Hermione is in Gryffingor
# Harry is in Gryffingor
# Ron is in Gryffingor
# Draco is in Slythering

# %%
students = []

with open("students.csv") as file:
    for line in file:
        name, house = line.rstrip().split(",")
        students.append(f"{name} is in {house}")

for students in sorted(students):
    print(students)

# ! this is no good
# Out:
# Draco is in Slythering
# Harry is in Gryffingor
# Hermione is in Gryffingor
# Ron is in Gryffingor

# %%
# use dict for sorting
students = []

with open("students.csv") as file:
    for line in file:
        name, house = line.rstrip().split(",")
        # student = {}
        # student["name"] = name
        # student["house"] = house
        student = {"name": name, "house": house}  # * simple way
        students.append(student)


def get_name(student):
    return student["name"]


def get_house(house):
    return student["house"]


for student in sorted(students, key=get_house, reverse=True):
    print(f"{student['name']} is in {student['house']}")
# Out:
# Hermione is in Gryffingor
# Harry is in Gryffingor
# Ron is in Gryffingor
# Draco is in Slythering

# %% [markdown]
# `lambda arguments: expression`
#
# - lambda: The keyword that tells Python you are creating an anonymous function.
# - arguments: The input values (just like a normal function). You can have multiple arguments separated by commas.
# - expression: A single line of code that is executed and automatically returned.

# %%
# using lambda (this anonymous funtion. it uses when a funtion do not need a name. also can use this without a return value)
students = []

with open("students.csv") as file:
    for line in file:
        name, house = line.rstrip().split(",")
        student = {"name": name, "house": house}
        students.append(student)


for student in sorted(students, key=lambda student: student["name"]):
    print(f"{student['name']} is in {student['house']}")
# Out:
# 'Draco'

# %%
# lambda example

add = lambda x, y: x + y
print(add(2, 3))
# Out:
# 5

# %%
students = []

with open("students2.csv") as file:
    for line in file:
        name, home = line.rstrip().split(",")
        student = {"name": name, "home": home}
        students.append(student)


for student in sorted(students, key=lambda student: student["name"]):
    print(f"{student['name']} is from {student['home']}")

#! this will give an error (because is one row has 3 ",")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 5
#       3 with open("students2.csv") as file:
#       4     for line in file:
# ----> 5         name, home = line.rstrip().split(",")
#       6         student = {"name": name, "home": home}
#       7         students.append(student)
#
# ValueError: too many values to unpack (expected 2)

# %%
# using csv module in python
import csv

students = []

with open("students2.csv") as file:
    reader = csv.reader(file)  # list of coloumns
    for name, home in reader:
        students.append({"name": name, "home": home})

for student in sorted(students, key=lambda student: student["name"]):
    print(f"{student['name']} is from {student['home']}")
# Out:
# Draco is from Malfoy Manner
# Harry is from Number four, Privet Drive
# Ron is from The Burrow

# %%
import csv

students = []

with open("students3.csv") as file:
    reader = csv.DictReader(file)  # give this as a dict of coloumns
    for row in reader:
        students.append({"name": row["name"], "home": row["home"]})

for student in sorted(students, key=lambda student: student["name"]):
    print(f"{student['name']} is from {student['home']}")
# Out:
# Draco is from Malfoy Manner
# Harry is from Number four, Privet Drive
# Ron is from The Burrow

# %%
# write data

import csv

name = input("What's your name? ")
home = input("Where's your home? ")

with open("students4.csv", "a") as file:
    writer = csv.writer(file)
    writer.writerow([name, home])

# %%
# using dict

import csv

name = input("What's your name? ")
home = input("Where's your home? ")

with open("students4.csv", "a") as file:
    writer = csv.DictWriter(file, fieldnames=["name", "home"])
    writer.writerow({"name": name, "home": home})

# %% [markdown]
# ## Handle image

# %%
# see costumes.py for this.

# %% [markdown]
# `video time -> 8:32:56`

# %% [markdown]
# > # Regular Expressions (regexes)

# %%
# validate.py

email = input("What's your email? ").strip()  # get input and remove sespaces

if "@" in email and "." in email:
    print("Valid")
else:
    print("Invalid")
# Out:
# Valid

# %%
email = input("What's your email? ").strip()

username, domain = email.split("@")

if username and "." in domain:
    print("Valid")
else:
    print("Invalid")
# Out:
# Valid

# %%
email = input("What's your email? ").strip()

username, domain = email.split("@")

if username and domain.endswith(".edu"):
    print("Valid")
else:
    print("Invalid")
# Out:
# Valid

# %% [markdown]
# `re` -> library
#
# `re.search(pattern, string, flag=0`

# %% [markdown]
# uses `finite state machine` for detect these

# %%
# regexes
import re

email = input("What's your email? ").strip()

if re.search("@", email):  # is @ inside the email?
    print("Valid")
else:
    print("Invalid")
# Out:
# Valid

# %% [markdown]
# - `.` : any character except a new line
# - `*` : 0 or more repetitions
# - `+` : 1 or more repetitions
# - `?` : 0 or 1 repetitions
# - `{m}` : m repetitions
# - `{m,n}` : m-n repetitions
# - `^` : matches the start of the string
# - `$` : matches the end of the string or just before the newline at the end of the string
# - `[]` : set of characters (need to match)
# - `[^]` : complementing the set (can not match)

# %%
import re

email = input("What's your email? ").strip()

if re.search(".@", email):
    print("Valid")
else:
    print("Invalid")
# Out:
# Invalid

# %%
import re

email = input("What's your email? ").strip()

if re.search(".+@.+", email):  # .+ before @ and .+ after @
    print("Valid")
else:
    print("Invalid")
# Out:
# Valid

# %%
import re

email = input("What's your email? ").strip()

if re.search(
    "..*@..*", email
):  # `.` and `.*` (any character or any 0 or more charachters)
    print("Valid")
else:
    print("Invalid")

# %% [markdown]
# ![alt text](<screenshots/Screenshot 2025-12-02 at 18-24-08 (343) Harvard CS50’s Introduction to Programming with Python – Full University Course - YouTube.png>)
#
# ```python
# import re
#
# email = input("What's your email? ").strip()
#
# if re.search(".*@.*", email):
#     print("Valid")
# else:
#     print("Invalid")
# ```

# %% [markdown]
# ![alt text](<screenshots/Screenshot 2025-12-02 at 18-27-34 (343) Harvard CS50’s Introduction to Programming with Python – Full University Course - YouTube.png>)
#
# ```python
# import re
#
# email = input("What's your email? ").strip()
#
# if re.search(".+@.+", email):
#     print("Valid")
# else:
#     print("Invalid")
# ```

# %%
import re

email = input("What's your email? ").strip()

if re.search(
    ".+@.+.edu", email
):  #! problem: this is wrong because in .edu the '.' can be any charachter. (aedu, bedu)
    print("Valid")
else:
    print("Invalid")
# Out:
# Valid

# %%
import re

email = input("What's your email? ").strip()

if re.search(
    r".+@.+\.edu", email
):  # * now with the "\" it is going to check ".edu". with "r" this will get it as a raw string (Denotes a raw string in Python, which prevents backslashes from being interpreted as escape sequences by Python itself, leaving them for the regex engine.)
    print("Valid")
else:
    print("Invalid")

#! problem: "my email address is pasan@test.edu." -> this is still valid
# Out:
# Valid

# %%
import re

email = input("What's your email? ").strip()

if re.search(r"^.+@.+\.edu$", email):  # * user input start with this and end with .edu
    print("Valid")
else:
    print("Invalid")

## "my email address is pasan@test.edu." -> invalid / "my email address is pasan@test.edu" -> valid
#! problem : "pasan@@@test.edu" -> this is still valid
# Out:
# Invalid

# %%
import re

email = input("What's your email? ").strip()

if re.search(r"^[^@]+@[^@]+\.edu$", email):  # * [^@] -> every thing except "@"
    print("Valid")
else:
    print("Invalid")
# Out:
# Valid

# %%
# define characters that allow

import re

email = input("What's your email? ").strip()

if re.search(r"^[a-zA-Z0-9_]+@[a-zA-Z0-9_]+\.edu$", email):
    print("Valid")
else:
    print("Invalid")
# Out:
# Invalid

# %% [markdown]
# [a−zA−Z0−9_] = \w

# %%
# short method

import re

email = input("What's your email? ").strip()

if re.search(r"^\w+@\w+\.edu$", email):
    print("Valid")
else:
    print("Invalid")

# %%
# is some one want to add a space 

import re

email = input("What's your email? ").strip()

if re.search(r"^[a-zA-Z0-9_ ]+@[a-zA-Z0-9_ ]+\.edu$", email):
    print("Valid")
else:
    print("Invalid")

# %% [markdown]
# * `\d` = decimal digit (0-9)
# * `\D` = not a decimal digit (any character that isn't a number. eg -> a,@,D)
# * `\s` = whitespace character (space, tab, newline)
# * `\S` = not a whitespace character (any character that is not a space, tab, or newline)
# * `\w` = word character ... as well as numbers and the underscore (a−zA−Z0−9_)
# * `\W` = not a word character (punctuation and symbols)

# %% [markdown]
# * `A|B` : either A or B
# * `(...)` : a group
# * `(?:...)` : non-capturing version

# %%
# add some more domain other than one

import re

email = input("What's your email? ").strip()

if re.search(r"^\w+@\w+\.(edu|com|gov|net|org)$", email):
    print("Valid")
else:
    print("Invalid")
# Out:
# Valid

# %%
# if some one want to add a space

import re

email = input("What's your email? ").strip()

if re.search(r"^(\w|\s)+@(\w|\s)+\.(edu|com|gov|net|org)$", email):
    print("Valid")
else:
    print("Invalid")

# %%
# handle cases example 1

import re

email = input("What's your email? ").strip().lower()

if re.search(r"^(\w|\s)+@(\w|\s)+\.(edu|com|gov|net|org)$", email):
    print("Valid")
else:
    print("Invalid")
# Out:
# Valid

# %%
# handle cases example 2

import re

email = input("What's your email? ").strip()

if re.search(r"^(\w|\s)+@(\w|\s)+\.(edu|com|gov|net|org)$", email.lower()):
    print("Valid")
else:
    print("Invalid")

# %% [markdown]
# using `flags`
#
# * `re.IGNORECASE`
# * `re.MULTILINE`
# * `re.DORALL`

# %%
# handle cases example 3

import re

email = input("What's your email? ").strip()

if re.search(r"^(\w|\s)+@(\w|\s)+\.(edu|com|gov|net|org)$", email , re.IGNORECASE):
    print("Valid")
else:
    print("Invalid")


#! problem: how to handle emails like "abc@my.test.com"
# Out:
# Valid

# %%
import re

email = input("What's your email? ").strip()

if re.search(r"^(\w|\s)+@(\w|\s)+\.(\w|\s)+\.(edu|com|gov|net|org)$", email , re.IGNORECASE):
    print("Valid")
else:
    print("Invalid")

#! problem: now it can handle this "abc@my.test.com" but, now it can not handle this "abc@gmail.com"
# Out:
# Valid

# %%
import re

email = input("What's your email? ").strip()

if re.search(r"^(\w|\s)+@((\w|\s)?+\.)?(\w|\s)+\.(edu|com|gov|net|org)$", email , re.IGNORECASE): #* ((\w|\s)?+\.)? -> now this "?" make this optional
    print("Valid")
else:
    print("Invalid")
# Out:
# Invalid

# %% [markdown]
# **These are other methods in re library other than `re.search`**
#
# - `re.match(pattern, string, flags=0)`
# - `re.fullmatch(pattern, string, flags=0)`
# - `re.sub(pattern, repl, string, count=0 ,flags=0)`
# - `re.split(pattern, string, maxsplit=0, flags=0)`
# - `re.findall(pattern, string, flags=0)`

# %% [markdown]
# ### format user inputs

# %%
# format.py ->

name = input("What's your name? ").strip()
if "," in name:
    last, first = name.split(",")
    name = f"{first} {last}"
print(f"hello, {name}")

#! problem: what happend when names like this "David Malan, jr"
#! problem: what happend if user did not add a space (perera,pasan). this will shows a ValueError
# Out:
# hello,  pasan perera

# %% [markdown]
# * `(...)` : if use this this will return some values
# * `(?:...)` : this is not going to return anything

# %%
import re

name = input("What's your name? ").strip()
matches = re.search(r"^(.+), (.+)$", name)
if matches:
    # last, first = matches.groups()
    last = matches.group(1)
    first = matches.group(2)
    name = f"{first} {last}"
print(f"hello, {name}")
# Out:
# hello, perera pasan

# %%
# short way
import re

name = input("What's your name? ").strip()
matches = re.search(r"^(.+), (.+)$", name)
if matches:
    name = matches.group(2) + " " + matches.group(1)
print(f"hello, {name}")

#! problem: "lastname,firstname" -> if user did not enter a space the output will be like this "lastname,firstname". 
#* to solve this nee to add " ?"
# Out:
# hello, pasan perera

# %%
import re

name = input("What's your name? ").strip()
matches = re.search(r"^(.+), ?(.+)$", name)
if matches:
    name = matches.group(2) + " " + matches.group(1)
print(f"hello, {name}")

#! priblem: what happen if user input like this with large amount of spaces ("lastname,           firstmame"). now the ourput like this ("hello,          fistname lastname")
#* to fix this add " *"
# Out:
# hello,                  pasan perera

# %%
import re

name = input("What's your name? ").strip()
matches = re.search(r"^(.+), *(.+)$", name)
if matches:
    name = matches.group(2) + " " + matches.group(1)
print(f"hello, {name}")

# %% [markdown]
# `walrus operator" ( := )`

# %%
# short the code
import re

name = input("What's your name? ").strip()
if matches := re.search(r"^(.+), *(.+)$", name):
    name = matches.group(2) + " " + matches.group(1)
print(f"hello, {name}")
# Out:
# hello, pasan perera

# %%
# twitter.py
# eg: https://twitter.com/username

url = input("URL: ").strip()
username = url.replace("https://twitter.com/","")
print(f"Username: {username}")

#! problme: what if the url is http
#! problme: what if the url has other parameters
#! problme: what if user enter a link like this "my username is https://twitter.com/username" -> output: my username is username
#! problme: and so on
# Out:
# Username: username

# %% [markdown]
# `removeprefix` : The method takes one argument: the string you want to remove from the start of the original string.

# %%
url = input("URL: ").strip()
username = url.removeprefix("https://twitter.com/")
print(f"Username: {username}")

#! problem: still dose not work for some thing like this ("my username is https://twitter.com/username")
# Out:
# Username: username

# %% [markdown]
# `re.sub(pattern, repl, string, count=0 ,flags=0)`

# %%
import re
url = input("URL: ").strip()
username = re.sub(r"https://twitter.com/","",url)
print(f"Username: {username}")

#! problem: still dose not work for some thing like this ("my username is https://twitter.com/username")
# Out:
# Username: my username is username

# %%
import re

url = input("URL: ").strip()
username = re.sub(r"^(https?://)?(www\.)?twitter\.com/", "", url)
print(f"Username: {username}")

#! problem: what is user insert "https://google.com/" -> output: "Username: https://google.com/"
# Out:
# Username: username

# %%
# what if we use re.search

import re

url = input("URL: ").strip()
if matches := re.search(
    r"^https?://(?:www\.)?twitter\.(?:com|us|org)/(.+)$", url, re.IGNORECASE
):
    print(f"Username:", matches.group(1))


# * make sure (www\.) is like this (?:www\.). with this the www group will not return to the matches or capture the (www\.).
# Out:
# Username: username

# %%
# identify if the url top level domain is `com`
import re

url = input("URL: ").strip()
if matches := re.search(r"^https?://(?:www\.)?twitter\.(.+)/(.+)$", url, re.IGNORECASE):
    if matches.group(1) == "com":
        print(f"Username:", matches.group(2))
# Out:
# Username: username

# %%
# more precise
url = input("URL: ").strip()
if matches := re.search(
    r"^https?://(?:www\.)?twitter\.com/([a-z0-9_]+)$", url, re.IGNORECASE
):
    print(f"Username:", matches.group(1))
# Out:
# Username: username

# %% [markdown]
# `video time ->10:37:51`

# %% [markdown]
# ># Object-Oriented Programming

# %%
# student.py


def main():
    name = get_name()
    house = get_house()
    print(f"{name} form {house}")


def get_name():
    return input("Name: ")


def get_house():
    return input("House: ")


if __name__ == "__main__":
    main()
# Out:
# harry form gryffindor

# %%
# using tuple
#* this valuse are immutable
def main():
    name, house = get_student()
    print(f"{name} form {house}")


def get_student():
    name = input("Name: ")
    house = input("House: ")
    return name, house


if __name__ == "__main__":
    main()
# Out:
# harry ('harry', 'gryffindor')
# harry form ('harry', 'gryffindor')

# %%
def main():
    student = get_student()
    if student[0] == "Padma":
        student[1] = "Revenclaw"
    print(f"{student[0]} form {student[1]}")


def get_student():
    name = input("Name: ")
    house = input("House: ")
    return (name, house)


if __name__ == "__main__":
    main()

#! for the input of Padma and Gryffindor this will give an error: "TypeError: 'tuple' object does not support item assignment"
#! because valuse inside a tuple can not be changed (immutable)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 15
#      11     return (name, house)
#      14 if __name__ == "__main__":
# ---> 15     main()
#
# Cell In[9], line 4, in main()
#       2 student = get_student()
#       3 if student[0] == "Padma":
# ----> 4     student[1] = "Revenclaw"
#       5 print(f"{student[0]} form {student[1]}")
#
# TypeError: 'tuple' object does not support item assignment

# %%
# using dict


def main():
    student = get_student()
    print(f"{student['name']} form {student['house']}")


def get_student():
    student = {}
    student["name"] = input("Name: ")
    student["house"] = input("House: ")
    return student


if __name__ == "__main__":
    main()
# Out:
# Harry form Gryffindor

# %%
# short way


def main():
    student = get_student()
    print(f"{student['name']} form {student['house']}")


def get_student():
    name = input("Name: ")
    student = input("House: ")
    return {"name": name, "house": house}


if __name__ == "__main__":
    main()
# Out:
# Harry form gryffindor

# %%
# dict are mutable (valuse can be changed)


def main():
    student = get_student()
    if student["name"] == "Padma":
        student["house"] = "Ravenclaw"
    print(f"{student['name']} form {student['house']}")


def get_student():
    name = input("Name: ")
    student = input("House: ")
    return {"name": name, "house": house}


if __name__ == "__main__":
    main()
# Out:
# Padma form Ravenclaw

# %% [markdown]
# > ## classes
#
# allows to invent your own datatype in python and give them a name
#
# classes have atributes

# %%
class Student: ...


def main():
    student = get_student()
    print(f"{student.name} form {student.house}")


def get_student():
    student = Student()  # creating object of the Student class
    student.name = input("Name: ")  # student.name -> the "name" is atribute
    student.house = input("House: ")
    return student


if __name__ == "__main__":
    main()

# * now in here we have proper dtype named Student so we do not need to use tuples, dicts .
# * name and house are variables inside of a object that the type is Student
# Out:
# ...
# Harry form Gryffindor

# %% [markdown]
# `special methods`
#
# 01. `__init__` (dunder init) : instance variables(self.name, self.house)

# %%
class Student:
    def __init__(self, name, house):
        self.name = name # instance variable
        self.house = house # instance variable

# * with the self it give access to the object that currently created and it save name and student in this object


def main():
    student = get_student()
    print(f"{student.name} form {student.house}")


def get_student():
    name = input("Name: ")
    house = input("House: ")
    return Student(name, house)  # constructer cal;


if __name__ == "__main__":
    main()
# Out:
# d form d

# %%
# rais errors
class Student:
    def __init__(self, name, house):
        if not name:
            raise ValueError("Missing name")  # is name is empty raise exception
        if house not in ["Gryffindor", "Hyfflepuff", "Ravenclaw", "Slytherin"]:
            raise ValueError("Invalid house")
        self.name = name
        self.house = house


def main():
    student = get_student()
    print(f"{student.name} form {student.house}")


def get_student():
    name = input("Name: ")
    house = input("House: ")
    return Student(name, house)


if __name__ == "__main__":
    main()
# Out:
# Harry Potter form Gryffindor

# %% [markdown]
# 02. `__str__`: python automatically call this function for you any time some other function want to see your object as your as a tring

# %%
class Student:
    def __init__(self, name, house):
        if not name:
            raise ValueError("Missing name")
        if house not in ["Gryffindor", "Hyfflepuff", "Ravenclaw", "Slytherin"]:
            raise ValueError("Invalid house")
        self.name = name
        self.house = house

    def __str__(self):
        return f"{self.name} from {self.house}"


def main():
    student = get_student()
    print(student)


def get_student():
    name = input("Name: ")
    house = input("House: ")
    return Student(name, house)


if __name__ == "__main__":
    main()
# Out:
# Draco from Slytherin

# %% [markdown]
# method is a function is inside of a class

# %%
class Student:
    def __init__(self, name, house, patronus):
        if not name:
            raise ValueError("Missing name")
        if house not in ["Gryffindor", "Hyfflepuff", "Ravenclaw", "Slytherin"]:
            raise ValueError("Invalid house")
        self.name = name
        self.house = house
        self.patronus = patronus

    def __str__(self):
        return f"{self.name} from {self.house}"

    def charm(self):
        match self.patronus:
            case "Stag":
                return "🫏"
            case "Otter":
                return "🦦"
            case "Jack Russell terrier":
                return "🐶"
            case _:
                return "🪄"


def main():
    student = get_student()
    print("Expecto Patronum!")
    print(student.charm())


def get_student():
    name = input("Name: ")
    house = input("House: ")
    patronus = input("Patronus: ")
    return Student(name, house, patronus)


if __name__ == "__main__":
    main()
# Out:
# Expecto Patronum!
# 🪄

# %% [markdown]
# ## properties

# %% [markdown]
# @properties

# %% [markdown]
# ### decorators

# %%
class Student:
    def __init__(self, name, house):
        if not name:
            raise ValueError("Missing name")
        self.name = name  # still a instance variable
        self.house = house  # this is also going to call setter

    def __str__(self):
        return f"{self.name} from {self.house}"

    # * Getter (get some attributes)
    @property # this is a decorator
    def house(self):
        return self._house
        # instance variable (because the variable name is house this will collide with the setter name and getter name)

    # * Setter (set some valuse)
    @house.setter # this is a decorator
    def house(self, house):
        if house not in ["Gryffindor", "Hyfflepuff", "Ravenclaw", "Slytherin"]:
            raise ValueError("Invalid house")
        self._house = house  # instance variable


def main():
    student = get_student()
    # student.house = "Number Four, Privet Drive" # going to call the house setter inside the student calass
    print(student)


def get_student():
    name = input("Name: ")
    house = input("House: ")
    return Student(name, house)


if __name__ == "__main__":
    main()
# Out:
# Harry from Gryffindor

# %%
# for the name also
class Student:
    def __init__(self, name, house):
        self.name = name
        self.house = house

    def __str__(self):
        return f"{self.name} from {self.house}"

    # Getter
    @property
    def name(self):
        return self._name

    # Setter
    @name.setter
    def name(self, name):
        if not name:
            raise ValueError("Missing name")
        self._name = name

    # Getter
    @property
    def house(self):
        return self._house

    # Setter
    @house.setter
    def house(self, house):
        if house not in ["Gryffindor", "Hyfflepuff", "Ravenclaw", "Slytherin"]:
            raise ValueError("Invalid house")
        self._house = house


def main():
    student = get_student()
    print(student)


def get_student():
    name = input("Name: ")
    house = input("House: ")
    return Student(name, house)


if __name__ == "__main__":
    main()

#! problem: if in the main we call student._house, this will still allow to change the object value. in python there is no private, public thing like java
# Out:
# Harry from Gryffindor

# %% [markdown]
# * `int` is a class
# * `str` is a class
# * `str.strip()` is a method
# * `str.split()` is a class
# * `dict` is a class
# * `list` is a class
# * etc..

# %%
# type.py

print(type(50))
# Out:
# <class 'int'>

# %%
print(type("Hello, world"))
# Out:
# <class 'str'>

# %%
print(type([]))
# Out:
# <class 'list'>

# %%
print(type(list()))
# Out:
# <class 'list'>

# %%
print(type(()))
# Out:
# <class 'tuple'>

# %%
print(type({}))
# Out:
# <class 'dict'>

# %%
print(type(dict()))
# Out:
# <class 'dict'>

# %% [markdown]
# ## class methods

# %% [markdown]
# `@classmethod`

# %%
# hat.py
import random


class Hat:
    def __init__(self):
        self.houses = ["Gryffindor", "Hyfflepuff", "Ravenclaw", "Slytherin"]

    def sort(self, name):
        print(name, "is in", random.choice(self.houses))


hat = Hat()
hat.sort("Harry")

#! problem: what if we only need one hat. because now we can create more hats like this -> hat1 = Hat() | hat2 = Hat() | hat3 = Hat() ....
# Out:
# Harry is in Gryffindor

# %%
import random


class Hat:
    houses = ["Gryffindor", "Hyfflepuff", "Ravenclaw", "Slytherin"]

    @classmethod
    def sort(cls, name):
        print(name, "is in", random.choice(cls.houses))


Hat.sort("Harry")
# Out:
# Harry is in Slytherin

# %%
# get all student related thing under student class


class Student:
    def __init__(self, name, house):
        self.name = name
        self.house = house

    def __str__(self):
        return f"{self.name} from {self.house}"

    @classmethod
    def get(cls):  # cls means the current class it self
        name = input("Name: ")
        house = input("House: ")
        return cls(name, house)


def main():
    student = Student.get()
    print(student)


if __name__ == "__main__":
    main()
# Out:
# hello harry
# harry from Gryffindor

# %%
# can add other method inside the class


class Student:
    def __init__(self, name, house):
        self.name = name
        self.house = house

    def __str__(self):
        return f"{self.name} from {self.house}"

    def test(self):
        print("hello", self.name)

    @classmethod
    def get(cls):  # cls means the current class it self
        name = input("Name: ")
        house = input("House: ")
        return cls(name, house)


def main():
    student = Student.get()
    student.test()
    print(student)


if __name__ == "__main__":
    main()
# Out:
# hello harry
# harry from Gryffindor

# %% [markdown]
# there is other methods are like this
#
# * **static method - > this used `@staticmethod`**

# %% [markdown]
# ## inheritence
#
# allow one class to borrow other classes method and things is they are similar

# %%
class Student:
    def __init__(self, name, house):
        if not name:
            raise ValueError("Missing name")
        self.name = name
        self.house = house

    ...


class Professor:
    def __init__(self, name, subject):
        if not name:
            raise ValueError("Missing name")
        self.name = name
        self.subject = subject


    ...

#! this is not good. because they use same thing again

# %%
class Wizard:
    def __init__(self, name):
        if not name:
            raise ValueError("Missing name")
        self.name = name

    ...


class Student(Wizard):  # Student is a subclass of Wizard or Student inherit form Wizard
    def __init__(self, name, house):
        # supper -> is the Wizard class and this calls the Wizard class __init__ method and pass the name
        super().__init__(name)
        self.house = house

    def __str__(self):
        return f"{self.name} if in {self.house}"

    ...


class Professor(Wizard):
    def __init__(self, name, subject):
        super().__init__(name)
        self.subject = subject

    def __str__(self):
        return f"{self.name} teaches {self.subject}"

    ...


wizard = Wizard("Albus")  # if some one wanted only a wizard
student = Student("Harry", "Gryffindor")
print(student)
professor = Professor("Severus", "Defense Against the Dark Arts")
print(professor)
# Out:
# Harry if in Gryffindor
# Severus teaches Defense Against the Dark Arts

# %% [markdown]
# BaseException
#
# ```
# |-- KeyboardInterrupt
# |-- Exception
#     |-- ArithmeticError
#         |-- ZeroDicisionError
#     |-- AssertionError
#     |-- AttributeError
#     |-- EOFError
#     |-- ImportError
#         |-- ModuleNotFoundError
#     |-- LookupError
#         |-- KeyError
#     |-- NameError
#     |-- SyntaxError
#         |-- IndentationError
#     |-- ValueError
# ...
# ```

# %% [markdown]
# ## operator overloading

# %%
# vault.py


class Vault:
    def __init__(self, galleons=0, sickles=0, knuts=0):
        self.galleons = galleons
        self.sickles = sickles
        self.knuts = knuts

    def __str__(self):
        return f"{self.galleons} Galleons, {self.sickles} Sickles, {self.knuts} Knuts"


potter = Vault(100, 50, 25)
print(potter)

weasley = Vault(25, 50, 100)
print(weasley)

galleons = potter.galleons + weasley.galleons
sickles = potter.sickles + weasley.sickles
knuts = potter.knuts + weasley.knuts

total = Vault(galleons, sickles, knuts)
print(total)
# Out:
# 100 Galleons, 50 Sickles, 25 Knuts
# 25 Galleons, 50 Sickles, 100 Knuts
# 125 Galleons, 100 Sickles, 125 Knuts

# %% [markdown]
# with overloading
#
# `object.__add__(self, other)`
#
# left(self) + right(other)

# %%
class Vault:
    def __init__(self, galleons=0, sickles=0, knuts=0):
        self.galleons = galleons
        self.sickles = sickles
        self.knuts = knuts

    def __str__(self):
        return f"{self.galleons} Galleons, {self.sickles} Sickles, {self.knuts} Knuts"


potter = Vault(100, 50, 25)
print(potter)

weasley = Vault(25, 50, 100)
print(weasley)

total = potter + weasley
print(total)

#! Problem: Error -> "TypeError: unsupported operand type(s) for +: 'Vault' and 'Vault'"
# Out:
# 100 Galleons, 50 Sickles, 25 Knuts
# 25 Galleons, 50 Sickles, 100 Knuts
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 17
#      14 weasley = Vault(25, 50, 100)
#      15 print(weasley)
# ---> 17 total = potter + weasley
#      18 print(total)
#      20 #! Problem: Error -> "TypeError: unsupported operand type(s) for +: 'Vault' and 'Vault'"
#
# TypeError: unsupported operand type(s) for +: 'Vault' and 'Vault'

# %%
class Vault:
    def __init__(self, galleons=0, sickles=0, knuts=0):
        self.galleons = galleons
        self.sickles = sickles
        self.knuts = knuts

    def __str__(self):
        return f"{self.galleons} Galleons, {self.sickles} Sickles, {self.knuts} Knuts"

    def __add__(self, other):  # overloaded operator
        galleons = self.galleons + other.galleons
        sickles = self.sickles + other.sickles
        knuts = self.knuts + other.knuts
        return Vault(galleons, sickles, knuts)


potter = Vault(100, 50, 25)
print(potter)

weasley = Vault(25, 50, 100)
print(weasley)

total = potter + weasley
print(total)
# Out:
# 100 Galleons, 50 Sickles, 25 Knuts
# 25 Galleons, 50 Sickles, 100 Knuts
# 125 Galleons, 100 Sickles, 125 Knuts

# %% [markdown]
# https://docs.python.org/3/reference/datamodel.html#special-method-names

# %% [markdown]
# `video time -> 13:29:06`
