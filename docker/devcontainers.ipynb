# %% [markdown]
# with dockerfile

# %% [markdown]
# devcontainer.json
# ```yml
# {
# 	"name": "Ubuntu",
# 	 "build":{
# 	 	"dockerfile": "Dockerfile"
# 	 }
# }
# ```
#
# dockerfile
# ```Dockerfile
# FROM mcr.microsoft.com/devcontainers/base:noble
#
# # use apt-get for docker files
# RUN apt-get update && apt-get install -y gimp
# ```

# %% [markdown]
# with compose

# %% [markdown]
# devcontainer.json
# ```yml
# {
# 	"name": "Ubuntu",
# 	"dockerComposeFile" : "docker-compose.yml",
# 	"service": "devcontainer",
# 	"workspaceFolder": "/workspace/${localWorkspaceFolderBasename}"
# }
# ```
#
#
# add the docker-compose.yml file inside the same folder

# %% [markdown]
# after setting up this run with
#
# Dev container: reopen folder locally in ctrl+shift+p

# %% [markdown]
# to use prebuild codespaces
#
# https://docs.github.com/en/codespaces/prebuilding-your-codespaces/about-github-codespaces-prebuilds
