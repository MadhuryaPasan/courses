# %% [markdown]
# nstall Reflex and create a new project. This will create a new directory structure in our project directory.
#
#     Note: When prompted to select a template, choose option 0 for a blank project.

# %% [markdown]
# ```bash
# chatapp $ pip install reflex
# chatapp $ reflex init
# ────────────────────────────────── Initializing chatapp ───────────────────────────────────
# Success: Initialized chatapp
# chatapp $ ls
# assets          chatapp         rxconfig.py     venv
# ```

# %% [markdown]
# ```bash
# chatapp $ reflex run
# ─────────────────────────────────── Starting Reflex App ───────────────────────────────────
# Compiling:  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 1/1 0:00:00
# ─────────────────────────────────────── App Running ───────────────────────────────────────
# App running at: http://localhost:3000
# ```
